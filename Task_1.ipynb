# %% [markdown]
# <a href="https://colab.research.google.com/github/aadityaa9111/DATA-PIPELINE-DEVELOPMENT/blob/main/Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('Titanic-Dataset.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df = df.drop(columns=['Name','Ticket','Cabin'])
df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0            1         0       3    male  22.0      1      0   7.2500        S
# 1            2         1       1  female  38.0      1      0  71.2833        C
# 2            3         1       3  female  26.0      0      0   7.9250        S
# 3            4         1       1  female  35.0      1      0  53.1000        S
# 4            5         0       3    male  35.0      0      0   8.0500        S

# %%
df['Sex'] = df['Sex'].map({'male':0,'female':1})
df['Embarked'] = df['Embarked'].map({'S':0,'C':1,'Q':2})
df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0            1         0       3    0  22.0      1      0   7.2500       0.0
# 1            2         1       1    1  38.0      1      0  71.2833       1.0
# 2            3         1       3    1  26.0      0      0   7.9250       0.0
# 3            4         1       1    1  35.0      1      0  53.1000       0.0
# 4            5         0       3    0  35.0      0      0   8.0500       0.0

# %%
imputer = SimpleImputer(strategy='mean')
df[['Age','Fare']] = imputer.fit_transform(df[['Age','Fare']])
df['Embarked'] = df['Embarked'].fillna(0)
df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0            1         0       3    0  22.0      1      0   7.2500       0.0
# 1            2         1       1    1  38.0      1      0  71.2833       1.0
# 2            3         1       3    1  26.0      0      0   7.9250       0.0
# 3            4         1       1    1  35.0      1      0  53.1000       0.0
# 4            5         0       3    0  35.0      0      0   8.0500       0.0

# %%
features = ['Pclass','Sex','Age','SibSp','Parch','Fare','Embarked']
x = df[features]
y = df['Survived']

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size=0.2,random_state=42)

# %%
print("ETL Pipeline complete!")
print("Training Data Shape:",x_train.shape)
print("Testing Data Shape:",x_test.shape)
# Out:
# ETL Pipeline complete!
# Training Data Shape: (712, 7)
# Testing Data Shape: (179, 7)
